# %% [markdown]
# # 🎬 Samkok (Three Kingdoms 2010) 1080p Khmer Dub Muxer
# ### Complete 95-Episode Torrent + Khmer Audio Remuxer with PixelDrain & GDrive Auto-Upload
#
# - **1080p Video**: Jiang Hu 1080p HD Torrent (Zero Cloudflare Rate Limits, high-speed BitTorrent download via `aria2`)
# - **Khmer Audio**: TheKomsan Complete 95 Episodes (Rumble CDN)
# - **Output**: 1080p MKV Dual Audio (Khmer Dub + Original Mandarin Audio + Hardcoded English Subtitles)
# - **Storage**: Auto-cleans after each episode to stay strictly under 3 GB disk usage
# - **Upload**: Automatic upload to PixelDrain and/or Google Drive

# %%
# Step 1 (Optional): Mount Google Drive if you want outputs saved to Google Drive
# from google.colab import drive
# drive.mount('/content/drive')

# %%
# Step 2: Clone or Update repository
# !if [ -d "/content/skym3u-downloader" ]; then cd /content/skym3u-downloader && git pull; else git clone https://github.com/iamsherman1234/skym3u-downloader.git /content/skym3u-downloader; fi

# %%
# Step 3: Run Episode 90 to 95 (or change -s and -e for any episode range!)
# !bash /content/skym3u-downloader/run_colab.sh -s 90 -e 95

# %%
# Step 4: View PixelDrain Download Links
# !cat /content/samkok_work/pixeldrain_links.txt 2>/dev/null || cat /content/drive/MyDrive/ThreeKingdoms_1080p_Khmer/pixeldrain_links.txt 2>/dev/null
