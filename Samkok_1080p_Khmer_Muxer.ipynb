# %% [markdown]
# # 🎬 Samkok (Three Kingdoms 2010) 1080p Khmer Dub Muxer
# Automated pipeline to mux Netflix 1080p WEB-DL video with high-quality Khmer dubbed audio directly into your Google Drive.

# %%
# Step 1: Mount Google Drive
from google.colab import drive
drive.mount('/content/drive')

# %%
# Step 2: Clone repository
# !git clone https://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@github.com/iamsherman1234/skym3u-downloader.git /content/skym3u-downloader
# %cd /content/skym3u-downloader

# %%
# Step 3: Run Episode 95
# !python3 colab_samkok_muxer.py -s 95 -e 95

# %%
# Optional: Run all episodes (1 to 95)
# !python3 colab_samkok_muxer.py -s 1 -e 95
