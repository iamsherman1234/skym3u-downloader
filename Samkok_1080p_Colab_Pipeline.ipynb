# %% [markdown]
# # 🎬 Samkok (Three Kingdoms 2010) 1080p Netflix Khmer Dub Muxer
# ### Complete 95-Episode Remuxer with Auto-Sync (+1.0s) & PixelDrain Auto-Uploader
#
# This notebook downloads 1080p Netflix video using 10MB bounded slice range chunks (bypassing Cloudflare rate limits), muxes Khmer audio with +1.0s hardware sync, and auto-uploads to PixelDrain.

# %%
# Step 1: Clone or update repository
# !if [ -d "/content/skym3u-downloader" ]; then cd /content/skym3u-downloader && git pull; else git clone https://github.com/iamsherman1234/skym3u-downloader /content/skym3u-downloader; fi

# %%
# Step 2: Run Pipeline (Example: Episodes 90 to 95)
# Change -s (start) and -e (end) to the episodes you want to process!
# !bash /content/skym3u-downloader/run_colab.sh -s 90 -e 95

# %%
# View uploaded PixelDrain Links
# !cat /content/samkok_work/pixeldrain_links.txt 2>/dev/null || cat /content/drive/MyDrive/ThreeKingdoms_1080p_Khmer/pixeldrain_links.txt 2>/dev/null
